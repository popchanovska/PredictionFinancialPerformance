# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

folder_path = '/content/drive/MyDrive/vnp-project/data/stocks'

dfs = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_path, file_name)

        df = pd.read_csv(file_path)

        dfs.append(df)

concatenated_df = pd.concat(dfs, ignore_index=True)

concatenated_df.to_csv('/content/drive/MyDrive/vnp-project/data/stocks.csv', index=False)

print("All CSV files have been concatenated.")
# Out:
# All CSV files have been concatenated.
