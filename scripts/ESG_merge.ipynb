# %%
import pandas as pd

# %%
prev_data = pd.read_csv("/content/drive/MyDrive/vnp-project/data/data.csv")
esg_scores = pd.read_csv("/content/drive/MyDrive/vnp-project/data/esg_ratings.csv")
data = pd.merge(prev_data, esg_scores, left_on="ticker", right_on="Ticker", how="left")

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.to_csv("/content/drive/MyDrive/vnp-project/data/data_with_esg.csv")
